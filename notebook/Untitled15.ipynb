# %% [markdown]
# <a href="https://colab.research.google.com/github/prisrum/PI_Mineria_Datos_1/blob/main/notebook/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(2)
# Out:
# 2
